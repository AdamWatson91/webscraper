# %%
import boto3

client = boto3.client('s3')

for
client.upload_file('/home/adamw/Documents/AiCore/webscraper/raw_data', 'watsonaicore', 'scraper_raw_data')
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# /tmp/ipykernel_24065/2378967778.py in <module>
#       2
#       3 client = boto3.client('s3')
# ----> 4 client.upload_file('/home/adamw/Documents/AiCore/webscraper/raw_data', 'watsonaicore', 'scraper_raw_data')
#
# ~/miniconda3/lib/python3.9/site-packages/boto3/s3/inject.py in upload_file(self, Filename, Bucket, Key, ExtraArgs, Callback, Config)
#     141     """
#     142     with S3Transfer(self, Config) as transfer:
# --> 143         return transfer.upload_file(
#     144             filename=Filename,
#     145             bucket=Bucket,
#
# ~/miniconda3/lib/python3.9/site-packages/boto3/s3/transfer.py in upload_file(self, filename, bucket, key, callback, extra_args)
#     286         )
#     287         try:
# --> 288             future.result()
# ...
